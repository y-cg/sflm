# %%
# !git clone https://github.com/y-cg/sflm.git
# %cd sflm

# %%
# !pip install uv

# %%
# Uncomment and set your S3 credentials when running in Google Colab
# import os
# from google.colab import userdata
# os.environ["S3_ENDPOINT_URL"] = userdata.get("S3_ENDPOINT_URL")
# os.environ["S3_ACCESS_KEY"] = userdata.get("S3_ACCESS_KEY")
# os.environ["S3_SECRET_KEY"] = userdata.get("S3_SECRET_KEY")
# os.environ["S3_BUCKET_NAME"] = "lightning"

# %%
# !uv run scripts/train_pl.py

# %%
# !uv run scripts/upload.py
